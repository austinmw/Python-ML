# %% [markdown]
# # [Plotly for IPython Notebooks](https://plot.ly/ipython-notebooks/getting-started/)
#
# ### [IPython Notebook Gallery](https://plot.ly/ipython-notebooks/)

# %% [markdown]
# ## Creating an interactive graph inside IPython notebook

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace0 = Scatter(
  x=[1, 2, 3, 4],
  y=[10, 15, 13, 17]
)
trace1 = Scatter(
  x=[1, 2, 3, 4],
  y=[16, 5, 11, 9]
)
data = Data([trace0, trace1])

py.iplot(data, filename = 'basic-line')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~austinmw/16.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Converting a matplotlib graph into an interactive graph inside an IPython notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import plotly.plotly as py

n = 50
x, y, z, s, ew = np.random.rand(5, n)
c, ec = np.random.rand(2, n, 4)
area_scale, width_scale = 500, 5

fig, ax = plt.subplots()
sc = ax.scatter(x, y, c=c,
                s=np.square(s)*area_scale,
                edgecolor=ec,
                linewidth=ew*width_scale)
ax.grid()

plt.show() # regular matplotlib graph

# %%
py.iplot_mpl(fig) # converting to plotly interactive
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~austinmw/20.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# ## Embedding a Plotly graph inside an IPython notebook

# %%
import plotly.tools as tls

tls.embed("https://plot.ly/~streaming-demos/4")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~streaming-demos/4.embed" height="525" width="100%"></iframe>
